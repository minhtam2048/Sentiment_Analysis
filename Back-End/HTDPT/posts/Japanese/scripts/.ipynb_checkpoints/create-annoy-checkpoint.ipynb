# %%
import numpy as np
from gensim.models import Word2Vec
from gensim import models

# %% [markdown]
# ### Word2Vec

# %%
word2vec = models.KeyedVectors.load_word2vec_format("/Users/bubuhuy/Downloads/sentiment-pj-download/baomoi.model.bin", binary=True)

# %%
word2vec.wv.vocab
# Out:
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# {'<punct>': <gensim.models.keyedvectors.Vocab at 0x10b26d250>,
#  '<number>': <gensim.models.keyedvectors.Vocab at 0x10b26d210>,
#  'của': <gensim.models.keyedvectors.Vocab at 0x1a1df81390>,
#  'và': <gensim.models.keyedvectors.Vocab at 0x1a1df813d0>,
#  'là': <gensim.models.keyedvectors.Vocab at 0x1a1df81410>,
#  'các': <gensim.models.keyedvectors.Vocab at 0x1a1df81490>,
#  'trong': <gensim.models.keyedvectors.Vocab at 0x1a1df814d0>,
#  'có': <gensim.models.keyedvectors.Vocab at 0x1a1df81550>,
#  'được': <gensim.models.keyedvectors.Vocab at 0x1a1df81590>,
#  'cho': <gensim.models.keyedvectors.Vocab at 0x1a1df815d0>,
#  'đã': <gensim.models.keyedvectors.Vocab at 0x1a1df81610>,
#  'với': <gensim.models.keyedvectors.Vocab at 0x1a1df81650>,
#  'không': <gensim.models.keyedvectors.Vocab at 0x1a1df81690>,
#  'một': <gensim.models.keyedvectors.Vocab at 0x1a1df816d0>,
#  'những': <gensim.models.keyedvectors.Vocab at 0x1a1df81710>,
#  'người': <gensim.models.keyedvectors.Vocab at 0x1a1df81750>,
#  'khi': <gensim.models.keyedvectors.Vocab at 0x1a1df817d0>,
#  'này': <gensim.models.keyedvectors.Vocab at 0x1a1df81810>,
#  'để': <gensim.models.keyedvectors.Vocab at 0x1a1df81850>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x1a1df81890>,
#  'ở': <gensim.models.keyedvectors.Vocab at 0x1a1df818d0>,
#  'về': <gensim.models.keyedvectors.Vocab at 0x1a1df81910>,
#  'năm': <gensim.models.keyedvectors.Vocab at 0x1a1df81950>,
#  'cũng': <gensim.models.keyedvectors.Vocab at 0x1a1df81990>,
#  'sẽ': <gensim.models.keyedvectors.Vocab at 0x1a1df819d0>,
#  'đến': <gensim.models.keyedvectors.Vocab at 0x1a1df81a10>,
#  'từ': <gensim.models.keyedvectors.Vocab at 0x1a1df81a50>,
#  'vào': <gensim.models.keyedvectors.Vocab at 0x1a1df81a90>,
#  'nhiều': <gensim.models.keyedvectors.Vocab at 0x1a1df81ad0>,
#  'tại': <gensim.models.keyedvectors.Vocab at 0x1a1df81b10>,
#  'trên': <gensim.models.keyedvectors.Vocab at 0x1a1df81b50>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x1a1df81b90>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x1a1df81bd0>,
#  'đó': <gensim.models.keyedvectors.Vocab at 0x1a1df81c10>,
#  'ra': <gensim.models.keyedvectors.Vocab at 0x1a1df81c90>,
#  'phải': <gensim.models.keyedvectors.Vocab at 0x1a1df81cd0>,
#  'ngày': <gensim.models.keyedvectors.Vocab at 0x1a1df81d10>,
#  'theo': <gensim.models.keyedvectors.Vocab at 0x1a1df81d90>,
#  'nhưng': <gensim.models.keyedvectors.Vocab at 0x1a1df81dd0>,
#  'như': <gensim.models.keyedvectors.Vocab at 0x1a1df81e10>,
#  'lại': <gensim.models.keyedvectors.Vocab at 0x1a1df81e50>,
#  'sau': <gensim.models.keyedvectors.Vocab at 0x1a1df81ed0>,
#  'còn': <gensim.models.keyedvectors.Vocab at 0x1a1df81f10>,
#  'hơn': <gensim.models.keyedvectors.Vocab at 0x1a1df81f50>,
#  'bị': <gensim.models.keyedvectors.Vocab at 0x1a1df81f90>,
#  'tôi': <gensim.models.keyedvectors.Vocab at 0x1a1df81fd0>,
#  'làm': <gensim.models.keyedvectors.Vocab at 0x1a1df86050>,
#  'anh': <gensim.models.keyedvectors.Vocab at 0x1a1df860d0>,
#  'việc': <gensim.models.keyedvectors.Vocab at 0x1a1df86110>,
#  'đang': <gensim.models.keyedvectors.Vocab at 0x1a1df86150>,
#  'thì': <gensim.models.keyedvectors.Vocab at 0x1a1df86190>,
#  'ông': <gensim.models.keyedvectors.Vocab at 0x1a1df861d0>,
#  'rất': <gensim.models.keyedvectors.Vocab at 0x1a1df86210>,
#  'việt_nam': <gensim.models.keyedvectors.Vocab at 0x1a1df86250>,
#  'trước': <gensim.models.keyedvectors.Vocab at 0x1a1df86290>,
#  'biết': <gensim.models.keyedvectors.Vocab at 0x1a1df862d0>,
#  'chỉ': <gensim.models.keyedvectors.Vocab at 0x1a1df86310>,
#  'đi': <gensim.models.keyedvectors.Vocab at 0x1a1df86350>,
#  'có_thể': <gensim.models.keyedvectors.Vocab at 0x1a1df86390>,
#  'mới': <gensim.models.keyedvectors.Vocab at 0x1a1df863d0>,
#  'sự': <gensim.models.keyedvectors.Vocab at 0x1a1df86410>,
#  'nhất': <gensim.models.keyedvectors.Vocab at 0x1a1df86450>,
#  'mình': <gensim.models.keyedvectors.Vocab at 0x1a1df86490>,
#  'đồng': <gensim.models.keyedvectors.Vocab at 0x1a1df864d0>,
#  'mà': <gensim.models.keyedvectors.Vocab at 0x1a1df86510>,
#  'bạn': <gensim.models.keyedvectors.Vocab at 0x1a1df86550>,
#  'vẫn': <gensim.models.keyedvectors.Vocab at 0x1a1df86590>,
#  'lên': <gensim.models.keyedvectors.Vocab at 0x1a1df865d0>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x1a1df86610>,
#  'nước': <gensim.models.keyedvectors.Vocab at 0x1a1df86650>,
#  'hai': <gensim.models.keyedvectors.Vocab at 0x1a1df866d0>,
#  'nhà': <gensim.models.keyedvectors.Vocab at 0x1a1df86710>,
#  'tới': <gensim.models.keyedvectors.Vocab at 0x1a1df86750>,
#  'nên': <gensim.models.keyedvectors.Vocab at 0x1a1df86790>,
#  'cùng': <gensim.models.keyedvectors.Vocab at 0x1a1df867d0>,
#  'tháng': <gensim.models.keyedvectors.Vocab at 0x1a1df86810>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x1a1df86850>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x1a1df868d0>,
#  'vì': <gensim.models.keyedvectors.Vocab at 0x1a1df86910>,
#  'giá': <gensim.models.keyedvectors.Vocab at 0x1a1df86950>,
#  'khác': <gensim.models.keyedvectors.Vocab at 0x1a1df86990>,
#  'qua': <gensim.models.keyedvectors.Vocab at 0x1a1df86a10>,
#  'tăng': <gensim.models.keyedvectors.Vocab at 0x1a1df86a50>,
#  'cả': <gensim.models.keyedvectors.Vocab at 0x1a1df86a90>,
#  'họ': <gensim.models.keyedvectors.Vocab at 0x1a1df86ad0>,
#  'bộ': <gensim.models.keyedvectors.Vocab at 0x1a1df86b10>,
#  'rằng': <gensim.models.keyedvectors.Vocab at 0x1a1df86b50>,
#  'cao': <gensim.models.keyedvectors.Vocab at 0x1a1df86bd0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x1a1df86c50>,
#  'cô': <gensim.models.keyedvectors.Vocab at 0x1a1df86c90>,
#  'chưa': <gensim.models.keyedvectors.Vocab at 0x1a1df86cd0>,
#  'nói': <gensim.models.keyedvectors.Vocab at 0x1a1df86d10>,
#  'lần': <gensim.models.keyedvectors.Vocab at 0x1a1df86d50>,
#  'nếu': <gensim.models.keyedvectors.Vocab at 0x1a1df86d90>,
#  'số': <gensim.models.keyedvectors.Vocab at 0x1a1df86dd0>,
#  'triệu': <gensim.models.keyedvectors.Vocab at 0x1a1df86e10>,
#  'đây': <gensim.models.keyedvectors.Vocab at 0x1a1df86e50>,
#  'lớn': <gensim.models.keyedvectors.Vocab at 0x1a1df86e90>,
#  'thấy': <gensim.models.keyedvectors.Vocab at 0x1a1df86ed0>,
#  'công_ty': <gensim.models.keyedvectors.Vocab at 0x1a1df86f10>,
#  'tiền': <gensim.models.keyedvectors.Vocab at 0x1a1df86f50>,
#  'hàng': <gensim.models.keyedvectors.Vocab at 0x1a1df86f90>,
#  'gần': <gensim.models.keyedvectors.Vocab at 0x1a1df86fd0>,
#  'cần': <gensim.models.keyedvectors.Vocab at 0x1a1df8c050>,
#  'hay': <gensim.models.keyedvectors.Vocab at 0x1a1df8c0d0>,
#  'bằng': <gensim.models.keyedvectors.Vocab at 0x1a1df8c110>,
#  'đưa': <gensim.models.keyedvectors.Vocab at 0x1a1df8c150>,
#  'thị_trường': <gensim.models.keyedvectors.Vocab at 0x1a1df8c190>,
#  'bên': <gensim.models.keyedvectors.Vocab at 0x1a1df8c1d0>,
#  'cuộc': <gensim.models.keyedvectors.Vocab at 0x1a1df8c210>,
#  'đầu': <gensim.models.keyedvectors.Vocab at 0x1a1df8c250>,
#  'giảm': <gensim.models.keyedvectors.Vocab at 0x1a1df8c290>,
#  'mức': <gensim.models.keyedvectors.Vocab at 0x1a1df8c2d0>,
#  'xe': <gensim.models.keyedvectors.Vocab at 0x1a1df8c350>,
#  'nay': <gensim.models.keyedvectors.Vocab at 0x1a1df8c3d0>,
#  'thứ': <gensim.models.keyedvectors.Vocab at 0x1a1df8c410>,
#  'thời_gian': <gensim.models.keyedvectors.Vocab at 0x1a1df8c450>,
#  'trận': <gensim.models.keyedvectors.Vocab at 0x1a1df8c490>,
#  'thêm': <gensim.models.keyedvectors.Vocab at 0x1a1df8c4d0>,
#  'tỷ': <gensim.models.keyedvectors.Vocab at 0x1a1df8c510>,
#  'mua': <gensim.models.keyedvectors.Vocab at 0x1a1df8c590>,
#  'bán': <gensim.models.keyedvectors.Vocab at 0x1a1df8c5d0>,
#  'tuổi': <gensim.models.keyedvectors.Vocab at 0x1a1df8c610>,
#  'hà_nội': <gensim.models.keyedvectors.Vocab at 0x1a1df8c650>,
#  'đường': <gensim.models.keyedvectors.Vocab at 0x1a1df8c690>,
#  'tổ_chức': <gensim.models.keyedvectors.Vocab at 0x1a1df8c6d0>,
#  'nào': <gensim.models.keyedvectors.Vocab at 0x1a1df8c710>,
#  'cách': <gensim.models.keyedvectors.Vocab at 0x1a1df8c750>,
#  'mỹ': <gensim.models.keyedvectors.Vocab at 0x1a1df8c790>,
#  'đều': <gensim.models.keyedvectors.Vocab at 0x1a1df8c7d0>,
#  'khiến': <gensim.models.keyedvectors.Vocab at 0x1a1df8c810>,
#  'chiếc': <gensim.models.keyedvectors.Vocab at 0x1a1df8c850>,
#  'khoảng': <gensim.models.keyedvectors.Vocab at 0x1a1df8c890>,
#  'tuy_nhiên': <gensim.models.keyedvectors.Vocab at 0x1a1df8c8d0>,
#  'em': <gensim.models.keyedvectors.Vocab at 0x1a1df8c950>,
#  'chính': <gensim.models.keyedvectors.Vocab at 0x1a1df8c990>,
#  'thực_hiện': <gensim.models.keyedvectors.Vocab at 0x1a1df8c9d0>,
#  'trung_quốc': <gensim.models.keyedvectors.Vocab at 0x1a1df8ca10>,
#  'đầu_tư': <gensim.models.keyedvectors.Vocab at 0x1a1df8ca50>,
#  'gì': <gensim.models.keyedvectors.Vocab at 0x1a1df8ca90>,
#  'nhau': <gensim.models.keyedvectors.Vocab at 0x1a1df8cb10>,
#  'bà': <gensim.models.keyedvectors.Vocab at 0x1a1df8cb50>,
#  'điểm': <gensim.models.keyedvectors.Vocab at 0x1a1df8cb90>,
#  'nhận': <gensim.models.keyedvectors.Vocab at 0x1a1df8cbd0>,
#  'hoặc': <gensim.models.keyedvectors.Vocab at 0x1a1df8cc10>,
#  'tp': <gensim.models.keyedvectors.Vocab at 0x1a1df8cc90>,
#  'tỉnh': <gensim.models.keyedvectors.Vocab at 0x1a1df8ccd0>,
#  'sử_dụng': <gensim.models.keyedvectors.Vocab at 0x1a1df8cd10>,
#  'chị': <gensim.models.keyedvectors.Vocab at 0x1a1df8cd50>,
#  'usd': <gensim.models.keyedvectors.Vocab at 0x1a1df8cdd0>,
#  'doanh_nghiệp': <gensim.models.keyedvectors.Vocab at 0x1a1df8ce10>,
#  'hoạt_động': <gensim.models.keyedvectors.Vocab at 0x1a1df8ce50>,
#  'phát_triển': <gensim.models.keyedvectors.Vocab at 0x1a1df8ce90>,
#  'ngân_hàng': <gensim.models.keyedvectors.Vocab at 0x1a1df8ced0>,
#  'một_số': <gensim.models.keyedvectors.Vocab at 0x1a1df8cf10>,
#  'xem': <gensim.models.keyedvectors.Vocab at 0x1a1df8cf90>,
#  'giữa': <gensim.models.keyedvectors.Vocab at 0x1a1df8cfd0>,
#  'kinh_tế': <gensim.models.keyedvectors.Vocab at 0x1a1df90050>,
#  'lúc': <gensim.models.keyedvectors.Vocab at 0x1a1df90090>,
#  'vừa': <gensim.models.keyedvectors.Vocab at 0x1a1df900d0>,
#  'chúng_tôi': <gensim.models.keyedvectors.Vocab at 0x1a1df90110>,
#  'xây_dựng': <gensim.models.keyedvectors.Vocab at 0x1a1df90150>,
#  'gia_đình': <gensim.models.keyedvectors.Vocab at 0x1a1df90190>,
#  'tốt': <gensim.models.keyedvectors.Vocab at 0x1a1df901d0>,
#  'từng': <gensim.models.keyedvectors.Vocab at 0x1a1df90210>,
#  'thế_giới': <gensim.models.keyedvectors.Vocab at 0x1a1df90250>,
#  'dự_án': <gensim.models.keyedvectors.Vocab at 0x1a1df90290>,
#  'vụ': <gensim.models.keyedvectors.Vocab at 0x1a1df902d0>,
#  'mang': <gensim.models.keyedvectors.Vocab at 0x1a1df90350>,
#  'gây': <gensim.models.keyedvectors.Vocab at 0x1a1df90390>,
#  'trẻ': <gensim.models.keyedvectors.Vocab at 0x1a1df903d0>,
#  'quá': <gensim.models.keyedvectors.Vocab at 0x1a1df90410>,
#  'tin': <gensim.models.keyedvectors.Vocab at 0x1a1df90490>,
#  'ngay': <gensim.models.keyedvectors.Vocab at 0x1a1df90510>,
#  'tiếp_tục': <gensim.models.keyedvectors.Vocab at 0x1a1df90550>,
#  'giúp': <gensim.models.keyedvectors.Vocab at 0x1a1df90590>,
#  'đội': <gensim.models.keyedvectors.Vocab at 0x1a1df905d0>,
#  'rồi': <gensim.models.keyedvectors.Vocab at 0x1a1df90610>,
#  'điều': <gensim.models.keyedvectors.Vocab at 0x1a1df90650>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1a1df906d0>,
#  'vốn': <gensim.models.keyedvectors.Vocab at 0x1a1df90710>,
#  'mọi': <gensim.models.keyedvectors.Vocab at 0x1a1df90750>,
#  'muốn': <gensim.models.keyedvectors.Vocab at 0x1a1df90790>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x1a1df907d0>,
#  'mỗi': <gensim.models.keyedvectors.Vocab at 0x10b243c50>,
#  'vàng': <gensim.models.keyedvectors.Vocab at 0x10b243690>,
#  'trường': <gensim.models.keyedvectors.Vocab at 0x10b243390>,
#  'đạt': <gensim.models.keyedvectors.Vocab at 0x10b243810>,
#  'thông_tin': <gensim.models.keyedvectors.Vocab at 0x10b243050>,
#  'khu_vực': <gensim.models.keyedvectors.Vocab at 0x10b2430d0>,
#  'ngoài': <gensim.models.keyedvectors.Vocab at 0x10b243150>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x10b243510>,
#  'bóng': <gensim.models.keyedvectors.Vocab at 0x10b1d0750>,
#  'dùng': <gensim.models.keyedvectors.Vocab at 0x10b1d0e50>,
#  'ấy': <gensim.models.keyedvectors.Vocab at 0x10b1d5c50>,
#  'Ông': <gensim.models.keyedvectors.Vocab at 0x10b1cbd10>,
#  'loại': <gensim.models.keyedvectors.Vocab at 0x10b1e4dd0>,
#  'mùa': <gensim.models.keyedvectors.Vocab at 0x1a1df90810>,
#  'cái': <gensim.models.keyedvectors.Vocab at 0x1a1df90850>,
#  'bởi': <gensim.models.keyedvectors.Vocab at 0x1a1df90890>,
#  'tạo': <gensim.models.keyedvectors.Vocab at 0x1a1df908d0>,
#  'đối_với': <gensim.models.keyedvectors.Vocab at 0x1a1df90910>,
#  'sáng': <gensim.models.keyedvectors.Vocab at 0x1a1df90950>,
#  'phía': <gensim.models.keyedvectors.Vocab at 0x1a1df90990>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1a1df909d0>,
#  'nơi': <gensim.models.keyedvectors.Vocab at 0x1a1df90a10>,
#  'giờ': <gensim.models.keyedvectors.Vocab at 0x1a1df90a50>,
#  'chương_trình': <gensim.models.keyedvectors.Vocab at 0x1a1df90a90>,
#  'mẹ': <gensim.models.keyedvectors.Vocab at 0x1a1df90ad0>,
#  'khá': <gensim.models.keyedvectors.Vocab at 0x1a1df90b10>,
#  'gái': <gensim.models.keyedvectors.Vocab at 0x1a1df90b50>,
#  'nó': <gensim.models.keyedvectors.Vocab at 0x1a1df90b90>,
#  'tham_gia': <gensim.models.keyedvectors.Vocab at 0x1a1df90bd0>,
#  'vấn_đề': <gensim.models.keyedvectors.Vocab at 0x1a1df90c50>,
#  'thi': <gensim.models.keyedvectors.Vocab at 0x1a1df90cd0>,
#  'phần': <gensim.models.keyedvectors.Vocab at 0x1a1df90d10>,
#  'luôn': <gensim.models.keyedvectors.Vocab at 0x1a1df90d50>,
#  'tìm': <gensim.models.keyedvectors.Vocab at 0x1a1df90d90>,
#  'tên': <gensim.models.keyedvectors.Vocab at 0x1a1df90dd0>,
#  'gặp': <gensim.models.keyedvectors.Vocab at 0x1a1df90e10>,
#  'người_dân': <gensim.models.keyedvectors.Vocab at 0x1a1df90e50>,
#  'huyện': <gensim.models.keyedvectors.Vocab at 0x1a1df90e90>,
#  'vn': <gensim.models.keyedvectors.Vocab at 0x1a1df90f10>,
#  'giải': <gensim.models.keyedvectors.Vocab at 0x1a1df90f50>,
#  'ăn': <gensim.models.keyedvectors.Vocab at 0x1a1df90f90>,
#  'diễn': <gensim.models.keyedvectors.Vocab at 0x1a1df90fd0>,
#  'khả_năng': <gensim.models.keyedvectors.Vocab at 0x1a1df95050>,
#  'tính': <gensim.models.keyedvectors.Vocab at 0x1a1df95090>,
#  'kinh_doanh': <gensim.models.keyedvectors.Vocab at 0x1a1df95110>,
#  'lấy': <gensim.models.keyedvectors.Vocab at 0x1a1df95150>,
#  'phim': <gensim.models.keyedvectors.Vocab at 0x1a1df951d0>,
#  'chính_phủ': <gensim.models.keyedvectors.Vocab at 0x1a1df95210>,
#  'học': <gensim.models.keyedvectors.Vocab at 0x1a1df95250>,
#  'bé': <gensim.models.keyedvectors.Vocab at 0x1a1df95290>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x1a1df95310>,
#  'tuần': <gensim.models.keyedvectors.Vocab at 0x1a1df95350>,
#  'quyết_định': <gensim.models.keyedvectors.Vocab at 0x1a1df95390>,
#  'cơ_quan': <gensim.models.keyedvectors.Vocab at 0x1a1df953d0>,
#  'đầu_tiên': <gensim.models.keyedvectors.Vocab at 0x1a1df95410>,
#  'không_thể': <gensim.models.keyedvectors.Vocab at 0x1a1df95450>,
#  'xuống': <gensim.models.keyedvectors.Vocab at 0x1a1df95490>,
#  'mất': <gensim.models.keyedvectors.Vocab at 0x1a1df954d0>,
#  'hiện': <gensim.models.keyedvectors.Vocab at 0x1a1df95510>,
#  'sản_phẩm': <gensim.models.keyedvectors.Vocab at 0x1a1df95550>,
#  'nhỏ': <gensim.models.keyedvectors.Vocab at 0x1a1df95590>,
#  'ngành': <gensim.models.keyedvectors.Vocab at 0x1a1df955d0>,
#  'thành_phố': <gensim.models.keyedvectors.Vocab at 0x1a1df95610>,
#  'nguồn': <gensim.models.keyedvectors.Vocab at 0x1a1df95650>,
#  'chuyện': <gensim.models.keyedvectors.Vocab at 0x1a1df95690>,
#  'công_an': <gensim.models.keyedvectors.Vocab at 0x1a1df956d0>,
#  'lời': <gensim.models.keyedvectors.Vocab at 0x1a1df95710>,
#  'cuối': <gensim.models.keyedvectors.Vocab at 0x1a1df95750>,
#  'giữ': <gensim.models.keyedvectors.Vocab at 0x1a1df95790>,
#  'phòng': <gensim.models.keyedvectors.Vocab at 0x1a1df957d0>,
#  'đặc_biệt': <gensim.models.keyedvectors.Vocab at 0x1a1df95810>,
#  'tàu': <gensim.models.keyedvectors.Vocab at 0x1a1df95850>,
#  'sản_xuất': <gensim.models.keyedvectors.Vocab at 0x1a1df95890>,
#  'đất': <gensim.models.keyedvectors.Vocab at 0x1a1df958d0>,
#  'cổ_phiếu': <gensim.models.keyedvectors.Vocab at 0x1a1df95910>,
#  'vòng': <gensim.models.keyedvectors.Vocab at 0x1a1df95950>,
#  'ai': <gensim.models.keyedvectors.Vocab at 0x1a1df959d0>,
#  'dưới': <gensim.models.keyedvectors.Vocab at 0x1a1df95a10>,
#  'quản_lý': <gensim.models.keyedvectors.Vocab at 0x1a1df95a50>,
#  'nhóm': <gensim.models.keyedvectors.Vocab at 0x1a1df95a90>,
#  'xã': <gensim.models.keyedvectors.Vocab at 0x1a1df95ad0>,
#  'thuộc': <gensim.models.keyedvectors.Vocab at 0x1a1df95b10>,
#  'sống': <gensim.models.keyedvectors.Vocab at 0x1a1df95b50>,
#  'nga': <gensim.models.keyedvectors.Vocab at 0x1a1df95bd0>,
#  'sang': <gensim.models.keyedvectors.Vocab at 0x1a1df95c50>,
#  'quy_định': <gensim.models.keyedvectors.Vocab at 0x1a1df95c90>,
#  'mạnh': <gensim.models.keyedvectors.Vocab at 0x1a1df95cd0>,
#  'biển': <gensim.models.keyedvectors.Vocab at 0x1a1df95d10>,
#  'chủ_tịch': <gensim.models.keyedvectors.Vocab at 0x1a1df95d50>,
#  'cấp': <gensim.models.keyedvectors.Vocab at 0x1a1df95d90>,
#  'dù': <gensim.models.keyedvectors.Vocab at 0x1a1df95dd0>,
#  'chủ': <gensim.models.keyedvectors.Vocab at 0x1a1df95e10>,
#  'ba': <gensim.models.keyedvectors.Vocab at 0x1a1df95e90>,
#  'giao_dịch': <gensim.models.keyedvectors.Vocab at 0x1a1df95ed0>,
#  'bài': <gensim.models.keyedvectors.Vocab at 0x1a1df95f10>,
#  'kể': <gensim.models.keyedvectors.Vocab at 0x1a1df95f50>,
#  'xảy': <gensim.models.keyedvectors.Vocab at 0x1a1df95f90>,
#  'nữa': <gensim.models.keyedvectors.Vocab at 0x1a1df95fd0>,
#  'thế': <gensim.models.keyedvectors.Vocab at 0x1a1df96050>,
#  'quốc_tế': <gensim.models.keyedvectors.Vocab at 0x1a1df96090>,
#  'hcm': <gensim.models.keyedvectors.Vocab at 0x1a1df96110>,
#  'đẹp': <gensim.models.keyedvectors.Vocab at 0x1a1df96150>,
#  'khu': <gensim.models.keyedvectors.Vocab at 0x1a1df961d0>,
#  'yêu_cầu': <gensim.models.keyedvectors.Vocab at 0x1a1df96210>,
#  'nhằm': <gensim.models.keyedvectors.Vocab at 0x1a1df96250>,
#  'nhà_nước': <gensim.models.keyedvectors.Vocab at 0x1a1df96290>,
#  'hỗ_trợ': <gensim.models.keyedvectors.Vocab at 0x1a1df962d0>,
#  'thành': <gensim.models.keyedvectors.Vocab at 0x1a1df96310>,
#  'quốc_gia': <gensim.models.keyedvectors.Vocab at 0x1a1df96350>,
#  'phút': <gensim.models.keyedvectors.Vocab at 0x1a1df96390>,
#  'khó_khăn': <gensim.models.keyedvectors.Vocab at 0x1a1df963d0>,
#  'đúng': <gensim.models.keyedvectors.Vocab at 0x1a1df96410>,
#  'Đây': <gensim.models.keyedvectors.Vocab at 0x1a1df96450>,
#  'hệ_thống': <gensim.models.keyedvectors.Vocab at 0x1a1df96490>,
#  'tay': <gensim.models.keyedvectors.Vocab at 0x1a1df96510>,
#  'tất_cả': <gensim.models.keyedvectors.Vocab at 0x1a1df96550>,
#  'đấu': <gensim.models.keyedvectors.Vocab at 0x1a1df96590>,
#  'đủ': <gensim.models.keyedvectors.Vocab at 0x1a1df965d0>,
#  'cầu_thủ': <gensim.models.keyedvectors.Vocab at 0x1a1df96610>,
#  'chiều': <gensim.models.keyedvectors.Vocab at 0x1a1df96650>,
#  'hiện_nay': <gensim.models.keyedvectors.Vocab at 0x1a1df96690>,
#  'Ảnh': <gensim.models.keyedvectors.Vocab at 0x1a1df966d0>,
#  'chồng': <gensim.models.keyedvectors.Vocab at 0x1a1df96710>,
#  'tài_chính': <gensim.models.keyedvectors.Vocab at 0x1a1df96750>,
#  'nam': <gensim.models.keyedvectors.Vocab at 0x1a1df967d0>,
#  'hết': <gensim.models.keyedvectors.Vocab at 0x1a1df96810>,
#  'kết_quả': <gensim.models.keyedvectors.Vocab at 0x1a1df96850>,
#  'bệnh': <gensim.models.keyedvectors.Vocab at 0x1a1df96890>,
#  'chơi': <gensim.models.keyedvectors.Vocab at 0x1a1df968d0>,
#  'khó': <gensim.models.keyedvectors.Vocab at 0x1a1df96910>,
#  'vợ': <gensim.models.keyedvectors.Vocab at 0x1a1df96950>,
#  'nhìn': <gensim.models.keyedvectors.Vocab at 0x1a1df96990>,
#  'thường': <gensim.models.keyedvectors.Vocab at 0x1a1df969d0>,
#  'rõ': <gensim.models.keyedvectors.Vocab at 0x1a1df96a10>,
#  'đặt': <gensim.models.keyedvectors.Vocab at 0x1a1df96a50>,
#  'vùng': <gensim.models.keyedvectors.Vocab at 0x1a1df96a90>,
#  'liên_quan': <gensim.models.keyedvectors.Vocab at 0x1a1df96ad0>,
#  'ít': <gensim.models.keyedvectors.Vocab at 0x1a1df96b10>,
#  'bỏ': <gensim.models.keyedvectors.Vocab at 0x1a1df96b50>,
#  'quan_trọng': <gensim.models.keyedvectors.Vocab at 0x1a1df96b90>,
#  'xã_hội': <gensim.models.keyedvectors.Vocab at 0x1a1df96bd0>,
#  'trở_thành': <gensim.models.keyedvectors.Vocab at 0x1a1df96c10>,
#  'quận': <gensim.models.keyedvectors.Vocab at 0x1a1df96c50>,
#  'kế_hoạch': <gensim.models.keyedvectors.Vocab at 0x1a1df96c90>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x1a1df96d10>,
#  'dành': <gensim.models.keyedvectors.Vocab at 0x1a1df96d50>,
#  'công_tác': <gensim.models.keyedvectors.Vocab at 0x1a1df96d90>,
#  'nữ': <gensim.models.keyedvectors.Vocab at 0x1a1df96dd0>,
#  'trung_tâm': <gensim.models.keyedvectors.Vocab at 0x1a1df96e10>,
#  'chia_sẻ': <gensim.models.keyedvectors.Vocab at 0x1a1df96e50>,
#  'thời_điểm': <gensim.models.keyedvectors.Vocab at 0x1a1df96e90>,
#  'ảnh': <gensim.models.keyedvectors.Vocab at 0x1a1df96ed0>,
#  'thấp': <gensim.models.keyedvectors.Vocab at 0x1a1df96f10>,
#  'làm_việc': <gensim.models.keyedvectors.Vocab at 0x1a1df96f50>,
#  'khách': <gensim.models.keyedvectors.Vocab at 0x1a1df96f90>,
#  'gửi': <gensim.models.keyedvectors.Vocab at 0x1a1df96fd0>,
#  'phó': <gensim.models.keyedvectors.Vocab at 0x1a1df9d050>,
#  'thành_công': <gensim.models.keyedvectors.Vocab at 0x1a1df9d090>,
#  'hlv': <gensim.models.keyedvectors.Vocab at 0x1a1df9d110>,
#  'lượng': <gensim.models.keyedvectors.Vocab at 0x1a1df9d150>,
#  'khỏi': <gensim.models.keyedvectors.Vocab at 0x1a1df9d190>,
#  'riêng': <gensim.models.keyedvectors.Vocab at 0x1a1df9d1d0>,
#  'yêu': <gensim.models.keyedvectors.Vocab at 0x1a1df9d210>,
#  'phát_hiện': <gensim.models.keyedvectors.Vocab at 0x1a1df9d250>,
#  'cơ_hội': <gensim.models.keyedvectors.Vocab at 0x1a1df9d290>,
#  'chết': <gensim.models.keyedvectors.Vocab at 0x1a1df9d2d0>,
#  'tiếng': <gensim.models.keyedvectors.Vocab at 0x1a1df9d310>,
#  'thủ_tướng': <gensim.models.keyedvectors.Vocab at 0x1a1df9d350>,
#  'khẳng_định': <gensim.models.keyedvectors.Vocab at 0x1a1df9d390>,
#  'máy_bay': <gensim.models.keyedvectors.Vocab at 0x1a1df9d3d0>,
#  'nằm': <gensim.models.keyedvectors.Vocab at 0x1a1df9d410>,
#  'sân': <gensim.models.keyedvectors.Vocab at 0x1a1df9d450>,
#  'lực_lượng': <gensim.models.keyedvectors.Vocab at 0x1a1df9d490>,
#  'hình_ảnh': <gensim.models.keyedvectors.Vocab at 0x1a1df9d4d0>,
#  'đơn_vị': <gensim.models.keyedvectors.Vocab at 0x1a1df9d510>,
#  'phiên': <gensim.models.keyedvectors.Vocab at 0x1a1df9d550>,
#  'việt': <gensim.models.keyedvectors.Vocab at 0x1a1df9d590>,
#  'như_vậy': <gensim.models.keyedvectors.Vocab at 0x1a1df9d5d0>,
#  'bắt_đầu': <gensim.models.keyedvectors.Vocab at 0x1a1df9d610>,
#  'bảo_vệ': <gensim.models.keyedvectors.Vocab at 0x1a1df9d650>,
#  'màu': <gensim.models.keyedvectors.Vocab at 0x1a1df9d690>,
#  'vay': <gensim.models.keyedvectors.Vocab at 0x1a1df9d710>,
#  'xuất_hiện': <gensim.models.keyedvectors.Vocab at 0x1a1df9d750>,
#  'xin': <gensim.models.keyedvectors.Vocab at 0x1a1df9d7d0>,
#  'ban': <gensim.models.keyedvectors.Vocab at 0x1a1df9d850>,
#  'đêm': <gensim.models.keyedvectors.Vocab at 0x1a1df9d890>,
#  'buổi': <gensim.models.keyedvectors.Vocab at 0x1a1df9d8d0>,
#  'hỏi': <gensim.models.keyedvectors.Vocab at 0x1a1df9d910>,
#  'thật': <gensim.models.keyedvectors.Vocab at 0x1a1df9d950>,
#  'mặt': <gensim.models.keyedvectors.Vocab at 0x1a1df9d990>,
#  'nước_ngoài': <gensim.models.keyedvectors.Vocab at 0x1a1df9d9d0>,
#  'cạnh': <gensim.models.keyedvectors.Vocab at 0x1a1df9da10>,
#  'đứng': <gensim.models.keyedvectors.Vocab at 0x1a1df9da50>,
#  'chung': <gensim.models.keyedvectors.Vocab at 0x1a1df9da90>,
#  'báo': <gensim.models.keyedvectors.Vocab at 0x1a1df9db10>,
#  'thay_đổi': <gensim.models.keyedvectors.Vocab at 0x1a1df9db50>,
#  'tự': <gensim.models.keyedvectors.Vocab at 0x1a1df9db90>,
#  'trường_hợp': <gensim.models.keyedvectors.Vocab at 0x1a1df9dbd0>,
#  'chạy': <gensim.models.keyedvectors.Vocab at 0x1a1df9dc10>,
#  'khách_hàng': <gensim.models.keyedvectors.Vocab at 0x1a1df9dc50>,
#  'bước': <gensim.models.keyedvectors.Vocab at 0x1a1df9dc90>,
#  'hãng': <gensim.models.keyedvectors.Vocab at 0x1a1df9dcd0>,
#  'điều_tra': <gensim.models.keyedvectors.Vocab at 0x1a1df9dd10>,
#  'tết': <gensim.models.keyedvectors.Vocab at 0x1a1df9dd50>,
#  'đôi': <gensim.models.keyedvectors.Vocab at 0x1a1df9dd90>,
#  'đáng': <gensim.models.keyedvectors.Vocab at 0x1a1df9ddd0>,
#  'dẫn': <gensim.models.keyedvectors.Vocab at 0x1a1df9de10>,
#  'chúng_ta': <gensim.models.keyedvectors.Vocab at 0x1a1df9de50>,
#  'phụ_nữ': <gensim.models.keyedvectors.Vocab at 0x1a1df9de90>,
#  'nghĩ': <gensim.models.keyedvectors.Vocab at 0x1a1df9ded0>,
#  'chọn': <gensim.models.keyedvectors.Vocab at 0x1a1df9df10>,
#  'gọi': <gensim.models.keyedvectors.Vocab at 0x1a1df9df50>,
#  'viết': <gensim.models.keyedvectors.Vocab at 0x1a1df9df90>,
#  'độ': <gensim.models.keyedvectors.Vocab at 0x1a1df9dfd0>,
#  'xử_lý': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3050>,
#  'dịch_vụ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3090>,
#  'tình_trạng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa30d0>,
#  'vị_trí': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3110>,
#  'điện': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3150>,
#  'giá_trị': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3190>,
#  'trở_lại': <gensim.models.keyedvectors.Vocab at 0x1a1dfa31d0>,
#  'địa_phương': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3210>,
#  'quan_hệ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3250>,
#  'đánh_giá': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3290>,
#  'hiệu_quả': <gensim.models.keyedvectors.Vocab at 0x1a1dfa32d0>,
#  'ảnh_hưởng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3310>,
#  'chuyển': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3350>,
#  'du_lịch': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3390>,
#  'vượt': <gensim.models.keyedvectors.Vocab at 0x1a1dfa33d0>,
#  'đối_tượng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3410>,
#  'nền': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3450>,
#  'thu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa34d0>,
#  'trai': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3550>,
#  'khoản': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3590>,
#  'lãnh_đạo': <gensim.models.keyedvectors.Vocab at 0x1a1dfa35d0>,
#  'chất_lượng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3610>,
#  'dài': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3650>,
#  'chống': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3690>,
#  'học_sinh': <gensim.models.keyedvectors.Vocab at 0x1a1dfa36d0>,
#  'kiểm_tra': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3710>,
#  'cơ_sở': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3750>,
#  'nghiên_cứu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3790>,
#  'vậy': <gensim.models.keyedvectors.Vocab at 0x1a1dfa37d0>,
#  'an_toàn': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3810>,
#  'bệnh_viện': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3850>,
#  'thực_tế': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3890>,
#  'sớm': <gensim.models.keyedvectors.Vocab at 0x1a1dfa38d0>,
#  'nhờ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3910>,
#  'trả': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3950>,
#  'cảnh_sát': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3990>,
#  'thiếu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa39d0>,
#  'Điều': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3a10>,
#  'nghe': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3a90>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3b10>,
#  'thậm_chí': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3b50>,
#  'thuế': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3b90>,
#  'dòng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3bd0>,
#  'hoàn_toàn': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3c10>,
#  'kỳ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3c50>,
#  'nhanh': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3c90>,
#  'giao_thông': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3d10>,
#  'công_bố': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3d50>,
#  'nội_dung': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3d90>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3dd0>,
#  'quý': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3e10>,
#  'án': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3e50>,
#  'chính_thức': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3e90>,
#  'hãy': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3ed0>,
#  'tổng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3f10>,
#  'mở': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3f50>,
#  'sinh': <gensim.models.keyedvectors.Vocab at 0x1a1dfa3fd0>,
#  'cuộc_sống': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8050>,
#  'nợ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8090>,
#  'lao_động': <gensim.models.keyedvectors.Vocab at 0x1a1dfa80d0>,
#  'điều_kiện': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8110>,
#  'nhà_đầu_tư': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8150>,
#  'vài': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8190>,
#  'chính_sách': <gensim.models.keyedvectors.Vocab at 0x1a1dfa81d0>,
#  'càng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8210>,
#  'công_nghệ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8250>,
#  'triển_khai': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8290>,
#  'cháu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa82d0>,
#  'bắt': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8310>,
#  'tập_trung': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8350>,
#  'hướng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8390>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1a1dfa83d0>,
#  'không_chỉ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8410>,
#  'câu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8450>,
#  'thuốc': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8490>,
#  'cá_nhân': <gensim.models.keyedvectors.Vocab at 0x1a1dfa84d0>,
#  'ngoài_ra': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8510>,
#  'tài_sản': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8550>,
#  'báo_cáo': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8590>,
#  'hợp_đồng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa85d0>,
#  'đảm_bảo': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8610>,
#  'thể_hiện': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8650>,
#  'nâng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8690>,
#  'quyền': <gensim.models.keyedvectors.Vocab at 0x1a1dfa86d0>,
#  'thương_mại': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8710>,
#  'máy': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8750>,
#  'giành': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8790>,
#  'miền': <gensim.models.keyedvectors.Vocab at 0x1a1dfa87d0>,
#  'lãi_suất': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8810>,
#  'thành_viên': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8850>,
#  'ubnd': <gensim.models.keyedvectors.Vocab at 0x1a1dfa88d0>,
#  'khán_giả': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8910>,
#  'hiểu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8950>,
#  'nhu_cầu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8990>,
#  'mạng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa89d0>,
#  'cầu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8a10>,
#  'văn_hóa': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8a50>,
#  'đánh': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8a90>,
#  'lượt': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8ad0>,
#  'giống': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8b10>,
#  'chẳng': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8b50>,
#  'dn': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8bd0>,
#  'chuẩn_bị': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8c10>,
#  'cán_bộ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8c50>,
#  'cụ_thể': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8c90>,
#  'lễ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8cd0>,
#  'quan_tâm': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8d10>,
#  'công_việc': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8d50>,
#  'chịu': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8d90>,
#  'Để': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8dd0>,
#  'sinh_viên': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8e10>,
#  'lĩnh_vực': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8e50>,
#  'thiết_kế': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8e90>,
#  'chứng_khoán': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8ed0>,
#  'chuyến': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8f10>,
#  'chứ': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8f50>,
#  'nhật_bản': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8f90>,
#  'môi_trường': <gensim.models.keyedvectors.Vocab at 0x1a1dfa8fd0>,
#  'lớp': <gensim.models.keyedvectors.Vocab at 0x1a1dfad050>,
#  'cứ': <gensim.models.keyedvectors.Vocab at 0x1a1dfad090>,
#  'trưởng': <gensim.models.keyedvectors.Vocab at 0x1a1dfad0d0>,
#  'giải_quyết': <gensim.models.keyedvectors.Vocab at 0x1a1dfad110>,
#  'giám_đốc': <gensim.models.keyedvectors.Vocab at 0x1a1dfad150>,
#  'chân': <gensim.models.keyedvectors.Vocab at 0x1a1dfad190>,
#  'đầy': <gensim.models.keyedvectors.Vocab at 0x1a1dfad1d0>,
#  'thích': <gensim.models.keyedvectors.Vocab at 0x1a1dfad210>,
#  'đá': <gensim.models.keyedvectors.Vocab at 0x1a1dfad250>,
#  'sở': <gensim.models.keyedvectors.Vocab at 0x1a1dfad290>,
#  'hiện_tại': <gensim.models.keyedvectors.Vocab at 0x1a1dfad2d0>,
#  'hát': <gensim.models.keyedvectors.Vocab at 0x1a1dfad310>,
#  'chuyên_gia': <gensim.models.keyedvectors.Vocab at 0x1a1dfad350>,
#  'quá_trình': <gensim.models.keyedvectors.Vocab at 0x1a1dfad390>,
#  'trực_tiếp': <gensim.models.keyedvectors.Vocab at 0x1a1dfad3d0>,
#  'tìm_kiếm': <gensim.models.keyedvectors.Vocab at 0x1a1dfad410>,
#  'tình_hình': <gensim.models.keyedvectors.Vocab at 0x1a1dfad450>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x1a1dfad490>,
#  'bất_ngờ': <gensim.models.keyedvectors.Vocab at 0x1a1dfad4d0>,
#  'Đt': <gensim.models.keyedvectors.Vocab at 0x1a1dfad510>,
#  'cây': <gensim.models.keyedvectors.Vocab at 0x1a1dfad550>,
#  'đâu': <gensim.models.keyedvectors.Vocab at 0x1a1dfad590>,
#  'thi_đấu': <gensim.models.keyedvectors.Vocab at 0x1a1dfad5d0>,
#  'món': <gensim.models.keyedvectors.Vocab at 0x1a1dfad610>,
#  'đồng_thời': <gensim.models.keyedvectors.Vocab at 0x1a1dfad650>,
#  'chiến_thắng': <gensim.models.keyedvectors.Vocab at 0x1a1dfad690>,
#  'trách_nhiệm': <gensim.models.keyedvectors.Vocab at 0x1a1dfad6d0>,
#  'xa': <gensim.models.keyedvectors.Vocab at 0x1a1dfad750>,
#  'dễ': <gensim.models.keyedvectors.Vocab at 0x1a1dfad790>,
#  'mục_tiêu': <gensim.models.keyedvectors.Vocab at 0x1a1dfad7d0>,
#  'giới': <gensim.models.keyedvectors.Vocab at 0x1a1dfad810>,
#  'hôm': <gensim.models.keyedvectors.Vocab at 0x1a1dfad850>,
#  'nhân_viên': <gensim.models.keyedvectors.Vocab at 0x1a1dfad890>,
#  'tỷ_lệ': <gensim.models.keyedvectors.Vocab at 0x1a1dfad8d0>,
#  'đăng_ký': <gensim.models.keyedvectors.Vocab at 0x1a1dfad910>,
#  'bản': <gensim.models.keyedvectors.Vocab at 0x1a1dfad950>,
#  'xuất_khẩu': <gensim.models.keyedvectors.Vocab at 0x1a1dfad990>,
#  'tăng_trưởng': <gensim.models.keyedvectors.Vocab at 0x1a1dfad9d0>,
#  'nhân_dân': <gensim.models.keyedvectors.Vocab at 0x1a1dfada10>,
#  'hợp_tác': <gensim.models.keyedvectors.Vocab at 0x1a1dfada50>,
#  'gồm': <gensim.models.keyedvectors.Vocab at 0x1a1dfada90>,
#  'quay': <gensim.models.keyedvectors.Vocab at 0x1a1dfadb10>,
#  'cuối_cùng': <gensim.models.keyedvectors.Vocab at 0x1a1dfadb50>,
#  'nặng': <gensim.models.keyedvectors.Vocab at 0x1a1dfadb90>,
#  'điện_thoại': <gensim.models.keyedvectors.Vocab at 0x1a1dfadbd0>,
#  'cung_cấp': <gensim.models.keyedvectors.Vocab at 0x1a1dfadc10>,
#  'nguyên_nhân': <gensim.models.keyedvectors.Vocab at 0x1a1dfadc50>,
#  'nổi_tiếng': <gensim.models.keyedvectors.Vocab at 0x1a1dfadc90>,
#  'một_cách': <gensim.models.keyedvectors.Vocab at 0x1a1dfadcd0>,
#  'hoa': <gensim.models.keyedvectors.Vocab at 0x1a1dfadd50>,
#  'tiến_hành': <gensim.models.keyedvectors.Vocab at 0x1a1dfadd90>,
#  'bàn': <gensim.models.keyedvectors.Vocab at 0x1a1dfaddd0>,
#  'mắt': <gensim.models.keyedvectors.Vocab at 0x1a1dfade10>,
#  'giai_đoạn': <gensim.models.keyedvectors.Vocab at 0x1a1dfade50>,
#  'Đó': <gensim.models.keyedvectors.Vocab at 0x1a1dfade90>,
#  'dân': <gensim.models.keyedvectors.Vocab at 0x1a1dfaded0>,
#  'châu_Âu': <gensim.models.keyedvectors.Vocab at 0x1a1dfadf10>,
#  'dự_kiến': <gensim.models.keyedvectors.Vocab at 0x1a1dfadf50>,
#  'cục': <gensim.models.keyedvectors.Vocab at 0x1a1dfadf90>,
#  'tiếp': <gensim.models.keyedvectors.Vocab at 0x1a1dfadfd0>,
#  'pháp': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3050>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x1a1dfb30d0>,
#  'tránh': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3110>,
#  'mặc_dù': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3150>,
#  'phù_hợp': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3190>,
#  'nạn_nhân': <gensim.models.keyedvectors.Vocab at 0x1a1dfb31d0>,
#  'chúng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3210>,
#  'hành_động': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3250>,
#  'giáo_dục': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3290>,
#  'mẫu': <gensim.models.keyedvectors.Vocab at 0x1a1dfb32d0>,
#  'toàn': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3310>,
#  'y_tế': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3350>,
#  'ngôi': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3390>,
#  'bảng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb33d0>,
#  'lòng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3410>,
#  'tập_đoàn': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3450>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3490>,
#  'sàn': <gensim.models.keyedvectors.Vocab at 0x1a1dfb34d0>,
#  'đại_diện': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3510>,
#  'ổn_định': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3550>,
#  'hành_vi': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3590>,
#  'hội': <gensim.models.keyedvectors.Vocab at 0x1a1dfb35d0>,
#  'cổ_phần': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3610>,
#  'thông_báo': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3650>,
#  'phường': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3690>,
#  'hàn_quốc': <gensim.models.keyedvectors.Vocab at 0x1a1dfb36d0>,
#  'đông': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3710>,
#  'nhiệm_vụ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3750>,
#  'đàn_ông': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3790>,
#  'xác_định': <gensim.models.keyedvectors.Vocab at 0x1a1dfb37d0>,
#  'đề_nghị': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3810>,
#  'luật': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3850>,
#  'lựa_chọn': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3890>,
#  'mối': <gensim.models.keyedvectors.Vocab at 0x1a1dfb38d0>,
#  'phối_hợp': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3910>,
#  'ý_kiến': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3950>,
#  'chelsea': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3990>,
#  'cũ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3a10>,
#  'ngồi': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3a50>,
#  'tấn': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3a90>,
#  'Đến': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3ad0>,
#  'tòa': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3b10>,
#  'diễn_viên': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3b50>,
#  'uống': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3b90>,
#  'đóng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3bd0>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3c10>,
#  'thông_qua': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3c50>,
#  'tấn_công': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3c90>,
#  'tuyến': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3cd0>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3d10>,
#  'vừa_qua': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3d50>,
#  'áo': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3d90>,
#  'tuyên_bố': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3dd0>,
#  'thực_sự': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3e10>,
#  'bộ_trưởng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3e50>,
#  'phục_vụ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3e90>,
#  'sức_khỏe': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3ed0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3f10>,
#  'pháp_luật': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3f50>,
#  'tối': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3f90>,
#  'lý_do': <gensim.models.keyedvectors.Vocab at 0x1a1dfb3fd0>,
#  'vị': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7050>,
#  'nhớ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7090>,
#  'giao': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7110>,
#  'chỉ_đạo': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7150>,
#  'tổng_thống': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7190>,
#  'suốt': <gensim.models.keyedvectors.Vocab at 0x1a1dfb71d0>,
#  'kiểm_soát': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7210>,
#  'bị_cáo': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7250>,
#  'bác_sĩ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7290>,
#  'lợi_nhuận': <gensim.models.keyedvectors.Vocab at 0x1a1dfb72d0>,
#  'sở_hữu': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7310>,
#  'mấy': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7350>,
#  'Ở': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7390>,
#  'tăng_cường': <gensim.models.keyedvectors.Vocab at 0x1a1dfb73d0>,
#  'vi_phạm': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7410>,
#  'sức': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7450>,
#  'quỹ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7490>,
#  'chiếm': <gensim.models.keyedvectors.Vocab at 0x1a1dfb74d0>,
#  'thuê': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7510>,
#  'bóng_đá': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7550>,
#  'chi_phí': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7590>,
#  'kỹ_thuật': <gensim.models.keyedvectors.Vocab at 0x1a1dfb75d0>,
#  'trả_lời': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7610>,
#  'an_ninh': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7650>,
#  'hôm_nay': <gensim.models.keyedvectors.Vocab at 0x1a1dfb76d0>,
#  'ukraine': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7710>,
#  'trang': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7790>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7810>,
#  'liên_tục': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7850>,
#  'thắng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7890>,
#  'bất_động_sản': <gensim.models.keyedvectors.Vocab at 0x1a1dfb78d0>,
#  'trái': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7910>,
#  'sông': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7950>,
#  'biện_pháp': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7990>,
#  'ghi': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7a10>,
#  'cậu': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7a50>,
#  'niềm': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7a90>,
#  'chỗ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7ad0>,
#  'trở': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7b10>,
#  'hộ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7b50>,
#  'ca_sĩ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7b90>,
#  'arsenal': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7bd0>,
#  'pha': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7c90>,
#  'mã': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7cd0>,
#  'chất': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7d10>,
#  'thường_xuyên': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7d50>,
#  'quả': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7d90>,
#  'cặp': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7dd0>,
#  'kết_thúc': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7e10>,
#  'km': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7e90>,
#  'tặng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7ed0>,
#  'bức': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7f10>,
#  'vợ_chồng': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7f50>,
#  'đỏ': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7f90>,
#  'lịch_sử': <gensim.models.keyedvectors.Vocab at 0x1a1dfb7fd0>,
#  'lâu': <gensim.models.keyedvectors.Vocab at 0x1a47db0050>,
#  'công_nghiệp': <gensim.models.keyedvectors.Vocab at 0x1a47db0090>,
#  'xanh': <gensim.models.keyedvectors.Vocab at 0x1a47db0110>,
#  'cộng_đồng': <gensim.models.keyedvectors.Vocab at 0x1a47db0150>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x1a47db01d0>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x1a47db0250>,
#  'thí_sinh': <gensim.models.keyedvectors.Vocab at 0x1a47db0290>,
#  'bắc': <gensim.models.keyedvectors.Vocab at 0x1a47db02d0>,
#  '+': <gensim.models.keyedvectors.Vocab at 0x1a47db0310>,
#  'bao_giờ': <gensim.models.keyedvectors.Vocab at 0x1a47db0350>,
#  'vì_vậy': <gensim.models.keyedvectors.Vocab at 0x1a47db0390>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x1a47db03d0>,
#  'Đức': <gensim.models.keyedvectors.Vocab at 0x1a47db0410>,
#  'công_trình': <gensim.models.keyedvectors.Vocab at 0x1a47db0450>,
#  'thiết_bị': <gensim.models.keyedvectors.Vocab at 0x1a47db0490>,
#  'đứa': <gensim.models.keyedvectors.Vocab at 0x1a47db04d0>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x1a47db0510>,
#  'chú_ý': <gensim.models.keyedvectors.Vocab at 0x1a47db0550>,
#  'nghề': <gensim.models.keyedvectors.Vocab at 0x1a47db0590>,
#  'quốc_hội': <gensim.models.keyedvectors.Vocab at 0x1a47db05d0>,
#  'toàn_bộ': <gensim.models.keyedvectors.Vocab at 0x1a47db0610>,
#  'tích_cực': <gensim.models.keyedvectors.Vocab at 0x1a47db0650>,
#  'chắc_chắn': <gensim.models.keyedvectors.Vocab at 0x1a47db0690>,
#  'hồi': <gensim.models.keyedvectors.Vocab at 0x1a47db06d0>,
#  'làng': <gensim.models.keyedvectors.Vocab at 0x1a47db0710>,
#  'đào_tạo': <gensim.models.keyedvectors.Vocab at 0x1a47db0750>,
#  'cá': <gensim.models.keyedvectors.Vocab at 0x1a47db0790>,
#  'hoàn_thành': <gensim.models.keyedvectors.Vocab at 0x1a47db07d0>,
#  'địa_bàn': <gensim.models.keyedvectors.Vocab at 0x1a47db0810>,
#  'bản_thân': <gensim.models.keyedvectors.Vocab at 0x1a47db0850>,
#  'điều_chỉnh': <gensim.models.keyedvectors.Vocab at 0x1a47db0890>,
#  'tốc_độ': <gensim.models.keyedvectors.Vocab at 0x1a47db08d0>,
#  'chụp': <gensim.models.keyedvectors.Vocab at 0x1a47db0910>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x1a47db0950>,
#  'hạnh_phúc': <gensim.models.keyedvectors.Vocab at 0x1a47db09d0>,
#  'coi': <gensim.models.keyedvectors.Vocab at 0x1a47db0a50>,
#  'ngôi_sao': <gensim.models.keyedvectors.Vocab at 0x1a47db0a90>,
#  'thôi': <gensim.models.keyedvectors.Vocab at 0x1a47db0ad0>,
#  'châu_Á': <gensim.models.keyedvectors.Vocab at 0x1a47db0b10>,
#  'chàng': <gensim.models.keyedvectors.Vocab at 0x1a47db0b50>,
#  'kinh_nghiệm': <gensim.models.keyedvectors.Vocab at 0x1a47db0b90>,
#  'trung_ương': <gensim.models.keyedvectors.Vocab at 0x1a47db0bd0>,
#  'trắng': <gensim.models.keyedvectors.Vocab at 0x1a47db0c10>,
#  'áp_dụng': <gensim.models.keyedvectors.Vocab at 0x1a47db0c50>,
#  'xấu': <gensim.models.keyedvectors.Vocab at 0x1a47db0c90>,
#  'cảm_thấy': <gensim.models.keyedvectors.Vocab at 0x1a47db0cd0>,
#  'tín_dụng': <gensim.models.keyedvectors.Vocab at 0x1a47db0d10>,
#  'sắp': <gensim.models.keyedvectors.Vocab at 0x1a47db0d50>,
#  'vai_trò': <gensim.models.keyedvectors.Vocab at 0x1a47db0d90>,
#  'nguyên': <gensim.models.keyedvectors.Vocab at 0x1a47db0dd0>,
#  'số_lượng': <gensim.models.keyedvectors.Vocab at 0x1a47db0e10>,
#  'chiến_lược': <gensim.models.keyedvectors.Vocab at 0x1a47db0e50>,
#  'nhạc': <gensim.models.keyedvectors.Vocab at 0x1a47db0e90>,
#  'thanh_niên': <gensim.models.keyedvectors.Vocab at 0x1a47db0ed0>,
#  'vô_địch': <gensim.models.keyedvectors.Vocab at 0x1a47db0f10>,
#  'Đảng': <gensim.models.keyedvectors.Vocab at 0x1a47db0f50>,
#  'Đh': <gensim.models.keyedvectors.Vocab at 0x1a47db0f90>,
#  'dự': <gensim.models.keyedvectors.Vocab at 0x1a47db0fd0>,
#  'có_mặt': <gensim.models.keyedvectors.Vocab at 0x1a47db6050>,
#  'ngày_càng': <gensim.models.keyedvectors.Vocab at 0x1a47db6090>,
#  'đại_học': <gensim.models.keyedvectors.Vocab at 0x1a47db60d0>,
#  'họp': <gensim.models.keyedvectors.Vocab at 0x1a47db6110>,
#  'chỉ_số': <gensim.models.keyedvectors.Vocab at 0x1a47db6150>,
#  'lập': <gensim.models.keyedvectors.Vocab at 0x1a47db6190>,
#  'đồ': <gensim.models.keyedvectors.Vocab at 0x1a47db61d0>,
#  'ủng_hộ': <gensim.models.keyedvectors.Vocab at 0x1a47db6210>,
#  'đoàn': <gensim.models.keyedvectors.Vocab at 0x1a47db6250>,
#  'mời': <gensim.models.keyedvectors.Vocab at 0x1a47db6290>,
#  'ký': <gensim.models.keyedvectors.Vocab at 0x1a47db62d0>,
#  'công': <gensim.models.keyedvectors.Vocab at 0x1a47db6310>,
#  'chờ': <gensim.models.keyedvectors.Vocab at 0x1a47db6350>,
#  'kg': <gensim.models.keyedvectors.Vocab at 0x1a47db63d0>,
#  'thực_phẩm': <gensim.models.keyedvectors.Vocab at 0x1a47db6410>,
#  'cú': <gensim.models.keyedvectors.Vocab at 0x1a47db6450>,
#  'khối': <gensim.models.keyedvectors.Vocab at 0x1a47db6490>,
#  'thu_hút': <gensim.models.keyedvectors.Vocab at 0x1a47db64d0>,
#  'rộng': <gensim.models.keyedvectors.Vocab at 0x1a47db6510>,
#  'Được': <gensim.models.keyedvectors.Vocab at 0x1a47db6550>,
#  'nổi': <gensim.models.keyedvectors.Vocab at 0x1a47db6590>,
#  'ô_tô': <gensim.models.keyedvectors.Vocab at 0x1a47db65d0>,
#  'ấn_tượng': <gensim.models.keyedvectors.Vocab at 0x1a47db6610>,
#  'tình_yêu': <gensim.models.keyedvectors.Vocab at 0x1a47db6650>,
#  'tỉ': <gensim.models.keyedvectors.Vocab at 0x1a47db6690>,
#  'dừng': <gensim.models.keyedvectors.Vocab at 0x1a47db66d0>,
#  'đảo': <gensim.models.keyedvectors.Vocab at 0x1a47db6710>,
#  'nghìn': <gensim.models.keyedvectors.Vocab at 0x1a47db6750>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x1a47db67d0>,
#  'hồ_sơ': <gensim.models.keyedvectors.Vocab at 0x1a47db6810>,
#  'thay': <gensim.models.keyedvectors.Vocab at 0x1a47db6890>,
#  'nhanh_chóng': <gensim.models.keyedvectors.Vocab at 0x1a47db68d0>,
#  'cổ': <gensim.models.keyedvectors.Vocab at 0x1a47db6910>,
#  'ra_mắt': <gensim.models.keyedvectors.Vocab at 0x1a47db6950>,
#  'cơ_thể': <gensim.models.keyedvectors.Vocab at 0x1a47db6990>,
#  'thể_thao': <gensim.models.keyedvectors.Vocab at 0x1a47db69d0>,
#  'lắm': <gensim.models.keyedvectors.Vocab at 0x1a47db6a10>,
#  'dịp': <gensim.models.keyedvectors.Vocab at 0x1a47db6a50>,
#  'tư_vấn': <gensim.models.keyedvectors.Vocab at 0x1a47db6a90>,
#  'giải_pháp': <gensim.models.keyedvectors.Vocab at 0x1a47db6ad0>,
#  'sâu': <gensim.models.keyedvectors.Vocab at 0x1a47db6b10>,
#  'chủ_yếu': <gensim.models.keyedvectors.Vocab at 0x1a47db6b50>,
#  'vai': <gensim.models.keyedvectors.Vocab at 0x1a47db6bd0>,
#  'hạn_chế': <gensim.models.keyedvectors.Vocab at 0x1a47db6c10>,
#  'nhẹ': <gensim.models.keyedvectors.Vocab at 0x1a47db6c50>,
#  'thái_lan': <gensim.models.keyedvectors.Vocab at 0x1a47db6c90>,
#  'mở_rộng': <gensim.models.keyedvectors.Vocab at 0x1a47db6cd0>,
#  'diện_tích': <gensim.models.keyedvectors.Vocab at 0x1a47db6d10>,
#  'rút': <gensim.models.keyedvectors.Vocab at 0x1a47db6d50>,
#  'tai_nạn': <gensim.models.keyedvectors.Vocab at 0x1a47db6d90>,
#  'nắm': <gensim.models.keyedvectors.Vocab at 0x1a47db6dd0>,
#  'phố': <gensim.models.keyedvectors.Vocab at 0x1a47db6e10>,
#  'điều_trị': <gensim.models.keyedvectors.Vocab at 0x1a47db6e50>,
#  'vui': <gensim.models.keyedvectors.Vocab at 0x1a47db6ed0>,
#  'cảnh': <gensim.models.keyedvectors.Vocab at 0x1a47db6f10>,
#  'nỗ_lực': <gensim.models.keyedvectors.Vocab at 0x1a47db6f50>,
#  'cười': <gensim.models.keyedvectors.Vocab at 0x1a47db6f90>,
#  'thời': <gensim.models.keyedvectors.Vocab at 0x1a47db6fd0>,
#  'vé': <gensim.models.keyedvectors.Vocab at 0x1a47db9050>,
#  'nguy_cơ': <gensim.models.keyedvectors.Vocab at 0x1a47db9090>,
#  'cp': <gensim.models.keyedvectors.Vocab at 0x1a47db9110>,
#  'chính_quyền': <gensim.models.keyedvectors.Vocab at 0x1a47db9150>,
#  'hình': <gensim.models.keyedvectors.Vocab at 0x1a47db9190>,
#  'máu': <gensim.models.keyedvectors.Vocab at 0x1a47db91d0>,
#  'bàn_thắng': <gensim.models.keyedvectors.Vocab at 0x1a47db9210>,
#  'đem': <gensim.models.keyedvectors.Vocab at 0x1a47db9250>,
#  'viện': <gensim.models.keyedvectors.Vocab at 0x1a47db9290>,
#  'ngủ': <gensim.models.keyedvectors.Vocab at 0x1a47db92d0>,
#  'tạm': <gensim.models.keyedvectors.Vocab at 0x1a47db9310>,
#  'thăm': <gensim.models.keyedvectors.Vocab at 0x1a47db9350>,
#  'dần': <gensim.models.keyedvectors.Vocab at 0x1a47db9390>,
#  'tinh_thần': <gensim.models.keyedvectors.Vocab at 0x1a47db93d0>,
#  'tương_lai': <gensim.models.keyedvectors.Vocab at 0x1a47db9410>,
#  'trời': <gensim.models.keyedvectors.Vocab at 0x1a47db9450>,
#  'bao_gồm': <gensim.models.keyedvectors.Vocab at 0x1a47db9490>,
#  'hấp_dẫn': <gensim.models.keyedvectors.Vocab at 0x1a47db94d0>,
#  'bệnh_nhân': <gensim.models.keyedvectors.Vocab at 0x1a47db9510>,
#  'cho_phép': <gensim.models.keyedvectors.Vocab at 0x1a47db9550>,
#  'đất_nước': <gensim.models.keyedvectors.Vocab at 0x1a47db9590>,
#  'kẻ': <gensim.models.keyedvectors.Vocab at 0x1a47db95d0>,
#  'nhà_máy': <gensim.models.keyedvectors.Vocab at 0x1a47db9610>,
#  'trở_nên': <gensim.models.keyedvectors.Vocab at 0x1a47db9650>,
#  'thanh': <gensim.models.keyedvectors.Vocab at 0x1a47db9690>,
#  'kiểu': <gensim.models.keyedvectors.Vocab at 0x1a47db9710>,
#  'nghệ_thuật': <gensim.models.keyedvectors.Vocab at 0x1a47db9750>,
#  'đợt': <gensim.models.keyedvectors.Vocab at 0x1a47db9790>,
#  'thời_trang': <gensim.models.keyedvectors.Vocab at 0x1a47db97d0>,
#  'sữa': <gensim.models.keyedvectors.Vocab at 0x1a47db9810>,
#  'cháy': <gensim.models.keyedvectors.Vocab at 0x1a47db9850>,
#  'giới_thiệu': <gensim.models.keyedvectors.Vocab at 0x1a47db9890>,
#  'xe_máy': <gensim.models.keyedvectors.Vocab at 0x1a47db98d0>,
#  'kéo_dài': <gensim.models.keyedvectors.Vocab at 0x1a47db9910>,
#  'con_người': <gensim.models.keyedvectors.Vocab at 0x1a47db9950>,
#  'lương': <gensim.models.keyedvectors.Vocab at 0x1a47db9990>,
#  'sự_kiện': <gensim.models.keyedvectors.Vocab at 0x1a47db99d0>,
#  'chục': <gensim.models.keyedvectors.Vocab at 0x1a47db9a10>,
#  'câu_chuyện': <gensim.models.keyedvectors.Vocab at 0x1a47db9a50>,
#  'Đà_nẵng': <gensim.models.keyedvectors.Vocab at 0x1a47db9a90>,
#  'barca': <gensim.models.keyedvectors.Vocab at 0x1a47db9ad0>,
#  'khai_thác': <gensim.models.keyedvectors.Vocab at 0x1a47db9b50>,
#  'nuôi': <gensim.models.keyedvectors.Vocab at 0x1a47db9b90>,
#  'hội_nghị': <gensim.models.keyedvectors.Vocab at 0x1a47db9bd0>,
#  'vì_thế': <gensim.models.keyedvectors.Vocab at 0x1a47db9c10>,
#  'thịt': <gensim.models.keyedvectors.Vocab at 0x1a47db9c50>,
#  'vụ_việc': <gensim.models.keyedvectors.Vocab at 0x1a47db9c90>,
#  'dầu': <gensim.models.keyedvectors.Vocab at 0x1a47db9cd0>,
#  'nóng': <gensim.models.keyedvectors.Vocab at 0x1a47db9d10>,
#  'cánh': <gensim.models.keyedvectors.Vocab at 0x1a47db9d50>,
#  'nhập_khẩu': <gensim.models.keyedvectors.Vocab at 0x1a47db9d90>,
#  'Ủy_ban': <gensim.models.keyedvectors.Vocab at 0x1a47db9dd0>,
#  'thua': <gensim.models.keyedvectors.Vocab at 0x1a47db9e50>,
#  'có_lẽ': <gensim.models.keyedvectors.Vocab at 0x1a47db9e90>,
#  'đơn': <gensim.models.keyedvectors.Vocab at 0x1a47db9ed0>,
#  'chợ': <gensim.models.keyedvectors.Vocab at 0x1a47db9f10>,
#  'tầm': <gensim.models.keyedvectors.Vocab at 0x1a47db9f50>,
#  'yếu_tố': <gensim.models.keyedvectors.Vocab at 0x1a47db9f90>,
#  'xong': <gensim.models.keyedvectors.Vocab at 0x1a47dbf050>,
#  'mặc': <gensim.models.keyedvectors.Vocab at 0x1a47dbf090>,
#  'nghỉ': <gensim.models.keyedvectors.Vocab at 0x1a47dbf0d0>,
#  'tiêu_dùng': <gensim.models.keyedvectors.Vocab at 0x1a47dbf110>,
#  'bổ_sung': <gensim.models.keyedvectors.Vocab at 0x1a47dbf150>,
#  'bình_thường': <gensim.models.keyedvectors.Vocab at 0x1a47dbf190>,
#  'bây_giờ': <gensim.models.keyedvectors.Vocab at 0x1a47dbf1d0>,
#  'trăm': <gensim.models.keyedvectors.Vocab at 0x1a47dbf210>,
#  'sẵn_sàng': <gensim.models.keyedvectors.Vocab at 0x1a47dbf250>,
#  'đối_thủ': <gensim.models.keyedvectors.Vocab at 0x1a47dbf290>,
#  'tình': <gensim.models.keyedvectors.Vocab at 0x1a47dbf2d0>,
#  'hàng_hóa': <gensim.models.keyedvectors.Vocab at 0x1a47dbf310>,
#  'thành_lập': <gensim.models.keyedvectors.Vocab at 0x1a47dbf350>,
#  'cố_gắng': <gensim.models.keyedvectors.Vocab at 0x1a47dbf390>,
#  'tấm': <gensim.models.keyedvectors.Vocab at 0x1a47dbf3d0>,
#  'trước_đây': <gensim.models.keyedvectors.Vocab at 0x1a47dbf410>,
#  'nêu': <gensim.models.keyedvectors.Vocab at 0x1a47dbf450>,
#  'khoa_học': <gensim.models.keyedvectors.Vocab at 0x1a47dbf490>,
#  'tình_cảm': <gensim.models.keyedvectors.Vocab at 0x1a47dbf4d0>,
#  'hề': <gensim.models.keyedvectors.Vocab at 0x1a47dbf510>,
#  'rõ_ràng': <gensim.models.keyedvectors.Vocab at 0x1a47dbf550>,
#  'đời': <gensim.models.keyedvectors.Vocab at 0x1a47dbf590>,
#  'duy_trì': <gensim.models.keyedvectors.Vocab at 0x1a47dbf5d0>,
#  'kém': <gensim.models.keyedvectors.Vocab at 0x1a47dbf610>,
#  'rơi': <gensim.models.keyedvectors.Vocab at 0x1a47dbf650>,
#  'clb': <gensim.models.keyedvectors.Vocab at 0x1a47dbf6d0>,
#  'chăm_sóc': <gensim.models.keyedvectors.Vocab at 0x1a47dbf710>,
#  'giấy': <gensim.models.keyedvectors.Vocab at 0x1a47dbf750>,
#  'sách': <gensim.models.keyedvectors.Vocab at 0x1a47dbf790>,
#  'quà': <gensim.models.keyedvectors.Vocab at 0x1a47dbf7d0>,
#  'quê': <gensim.models.keyedvectors.Vocab at 0x1a47dbf810>,
#  'đau': <gensim.models.keyedvectors.Vocab at 0x1a47dbf850>,
#  'tham_dự': <gensim.models.keyedvectors.Vocab at 0x1a47dbf890>,
#  'thủ_tục': <gensim.models.keyedvectors.Vocab at 0x1a47dbf8d0>,
#  'hạ': <gensim.models.keyedvectors.Vocab at 0x1a47dbf910>,
#  'đơn_giản': <gensim.models.keyedvectors.Vocab at 0x1a47dbf950>,
#  'mắc': <gensim.models.keyedvectors.Vocab at 0x1a47dbf990>,
#  'trung': <gensim.models.keyedvectors.Vocab at 0x1a47dbf9d0>,
#  'dân_tộc': <gensim.models.keyedvectors.Vocab at 0x1a47dbfa50>,
#  'cạnh_tranh': <gensim.models.keyedvectors.Vocab at 0x1a47dbfa90>,
#  'nhận_định': <gensim.models.keyedvectors.Vocab at 0x1a47dbfad0>,
#  'quán': <gensim.models.keyedvectors.Vocab at 0x1a47dbfb10>,
#  'con_số': <gensim.models.keyedvectors.Vocab at 0x1a47dbfb50>,
#  'Đ': <gensim.models.keyedvectors.Vocab at 0x1a47dbfb90>,
#  'phiên_bản': <gensim.models.keyedvectors.Vocab at 0x1a47dbfbd0>,
#  'nghèo': <gensim.models.keyedvectors.Vocab at 0x1a47dbfc10>,
#  'đoạn': <gensim.models.keyedvectors.Vocab at 0x1a47dbfc50>,
#  'đô_thị': <gensim.models.keyedvectors.Vocab at 0x1a47dbfc90>,
#  'tiền_vệ': <gensim.models.keyedvectors.Vocab at 0x1a47dbfcd0>,
#  'rời': <gensim.models.keyedvectors.Vocab at 0x1a47dbfd10>,
#  'danh_sách': <gensim.models.keyedvectors.Vocab at 0x1a47dbfd50>,
#  'thu_nhập': <gensim.models.keyedvectors.Vocab at 0x1a47dbfd90>,
#  'huy_động': <gensim.models.keyedvectors.Vocab at 0x1a47dbfdd0>,
#  'trao_đổi': <gensim.models.keyedvectors.Vocab at 0x1a47dbfe10>,
#  'nàng': <gensim.models.keyedvectors.Vocab at 0x1a47dbfe50>,
#  'sợ': <gensim.models.keyedvectors.Vocab at 0x1a47dbfe90>,
#  'tờ': <gensim.models.keyedvectors.Vocab at 0x1a47dbfed0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1a47dbff50>,
#  'chấp_nhận': <gensim.models.keyedvectors.Vocab at 0x1a47dbff90>,
#  'mới_đây': <gensim.models.keyedvectors.Vocab at 0x1a47dbffd0>,
#  'malaysia': <gensim.models.keyedvectors.Vocab at 0x1a47dc5050>,
#  'chi_tiết': <gensim.models.keyedvectors.Vocab at 0x1a47dc50d0>,
#  'mạnh_mẽ': <gensim.models.keyedvectors.Vocab at 0x1a47dc5110>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x1a47dc5150>,
#  'mưa': <gensim.models.keyedvectors.Vocab at 0x1a47dc5190>,
#  'tiền_đạo': <gensim.models.keyedvectors.Vocab at 0x1a47dc51d0>,
#  'kết_hợp': <gensim.models.keyedvectors.Vocab at 0x1a47dc5210>,
#  'màn_hình': <gensim.models.keyedvectors.Vocab at 0x1a47dc5250>,
#  'xuất_sắc': <gensim.models.keyedvectors.Vocab at 0x1a47dc5290>,
#  'hầu_hết': <gensim.models.keyedvectors.Vocab at 0x1a47dc52d0>,
#  'phát_biểu': <gensim.models.keyedvectors.Vocab at 0x1a47dc5310>,
#  'cứu': <gensim.models.keyedvectors.Vocab at 0x1a47dc5350>,
#  'dễ_dàng': <gensim.models.keyedvectors.Vocab at 0x1a47dc5390>,
#  'vô_cùng': <gensim.models.keyedvectors.Vocab at 0x1a47dc53d0>,
#  'cần_thiết': <gensim.models.keyedvectors.Vocab at 0x1a47dc5410>,
#  'hơn_nữa': <gensim.models.keyedvectors.Vocab at 0x1a47dc5450>,
#  'đáp_ứng': <gensim.models.keyedvectors.Vocab at 0x1a47dc5490>,
#  'căn_hộ': <gensim.models.keyedvectors.Vocab at 0x1a47dc54d0>,
#  'tập': <gensim.models.keyedvectors.Vocab at 0x1a47dc5510>,
#  'quân_đội': <gensim.models.keyedvectors.Vocab at 0x1a47dc5550>,
#  'môn': <gensim.models.keyedvectors.Vocab at 0x1a47dc5590>,
#  'báo_chí': <gensim.models.keyedvectors.Vocab at 0x1a47dc55d0>,
#  'hồ_chí_minh': <gensim.models.keyedvectors.Vocab at 0x1a47dc5610>,
#  'căn': <gensim.models.keyedvectors.Vocab at 0x1a47dc5650>,
#  'hè': <gensim.models.keyedvectors.Vocab at 0x1a47dc5690>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x1a47dc56d0>,
#  'truyền_thống': <gensim.models.keyedvectors.Vocab at 0x1a47dc5710>,
#  'doanh_thu': <gensim.models.keyedvectors.Vocab at 0x1a47dc5790>,
#  'tóc': <gensim.models.keyedvectors.Vocab at 0x1a47dc57d0>,
#  'bạn_bè': <gensim.models.keyedvectors.Vocab at 0x1a47dc5810>,
#  'bầu': <gensim.models.keyedvectors.Vocab at 0x1a47dc5850>,
#  'góp_phần': <gensim.models.keyedvectors.Vocab at 0x1a47dc5890>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x1a47dc5910>,
#  'liverpool': <gensim.models.keyedvectors.Vocab at 0x1a47dc5990>,
#  'trẻ_em': <gensim.models.keyedvectors.Vocab at 0x1a47dc59d0>,
#  'tái': <gensim.models.keyedvectors.Vocab at 0x1a47dc5a10>,
#  'chức_năng': <gensim.models.keyedvectors.Vocab at 0x1a47dc5a50>,
#  'xu_hướng': <gensim.models.keyedvectors.Vocab at 0x1a47dc5a90>,
#  'thương_hiệu': <gensim.models.keyedvectors.Vocab at 0x1a47dc5ad0>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x1a47dc5b10>,
#  'đón': <gensim.models.keyedvectors.Vocab at 0x1a47dc5b50>,
#  'trao': <gensim.models.keyedvectors.Vocab at 0x1a47dc5bd0>,
#  'thủ_đô': <gensim.models.keyedvectors.Vocab at 0x1a47dc5c10>,
#  'phương_tiện': <gensim.models.keyedvectors.Vocab at 0x1a47dc5c50>,
#  'hy_vọng': <gensim.models.keyedvectors.Vocab at 0x1a47dc5c90>,
#  'cựu': <gensim.models.keyedvectors.Vocab at 0x1a47dc5cd0>,
#  'tương_đương': <gensim.models.keyedvectors.Vocab at 0x1a47dc5d10>,
#  'phát_hành': <gensim.models.keyedvectors.Vocab at 0x1a47dc5d50>,
#  'ca_khúc': <gensim.models.keyedvectors.Vocab at 0x1a47dc5d90>,
#  'hòa': <gensim.models.keyedvectors.Vocab at 0x1a47dc5dd0>,
#  'chính_trị': <gensim.models.keyedvectors.Vocab at 0x1a47dc5e10>,
#  'cửa': <gensim.models.keyedvectors.Vocab at 0x1a47dc5e50>,
#  'đẩy': <gensim.models.keyedvectors.Vocab at 0x1a47dc5e90>,
#  'chở': <gensim.models.keyedvectors.Vocab at 0x1a47dc5ed0>,
#  'bất_cứ': <gensim.models.keyedvectors.Vocab at 0x1a47dc5f10>,
#  'xem_xét': <gensim.models.keyedvectors.Vocab at 0x1a47dc5f50>,
#  'khai': <gensim.models.keyedvectors.Vocab at 0x1a47dc5fd0>,
#  'tác_động': <gensim.models.keyedvectors.Vocab at 0x1a47dca050>,
#  'bảo': <gensim.models.keyedvectors.Vocab at 0x1a47dca090>,
#  'nghiêm_trọng': <gensim.models.keyedvectors.Vocab at 0x1a47dca0d0>,
#  'tung': <gensim.models.keyedvectors.Vocab at 0x1a47dca150>,
#  'nhân_vật': <gensim.models.keyedvectors.Vocab at 0x1a47dca190>,
#  'mà_còn': <gensim.models.keyedvectors.Vocab at 0x1a47dca1d0>,
#  'kiếm': <gensim.models.keyedvectors.Vocab at 0x1a47dca210>,
#  'nhất_là': <gensim.models.keyedvectors.Vocab at 0x1a47dca250>,
#  'cổ_đông': <gensim.models.keyedvectors.Vocab at 0x1a47dca290>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x1a47dca2d0>,
#  'hôm_qua': <gensim.models.keyedvectors.Vocab at 0x1a47dca310>,
#  'rừng': <gensim.models.keyedvectors.Vocab at 0x1a47dca350>,
#  'thỏa_thuận': <gensim.models.keyedvectors.Vocab at 0x1a47dca390>,
#  'đổ': <gensim.models.keyedvectors.Vocab at 0x1a47dca3d0>,
#  'tây': <gensim.models.keyedvectors.Vocab at 0x1a47dca410>,
#  'nguy_hiểm': <gensim.models.keyedvectors.Vocab at 0x1a47dca450>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x1a47dca490>,
#  ...}

# %%
from gensim.similarities.index import AnnoyIndexer

annoy_index = AnnoyIndexer(word2vec, 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c809234c42fe> in <module>
#       1 from gensim.similarities.index import AnnoyIndexer
#       2
# ----> 3 annoy_index = AnnoyIndexer(word2vec, 100)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gensim/similarities/index.py in __init__(self, model, num_trees)
#      95                 self.build_from_word2vec()
#      96             elif isinstance(self.model, (WordEmbeddingsKeyedVectors, KeyedVectors)):
# ---> 97                 self.build_from_keyedvectors()
#      98             else:
#      99                 raise ValueError("Only a Word2Vec, Doc2Vec, FastText or KeyedVectors instance can be used")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gensim/similarities/index.py in build_from_keyedvectors(self)
#     179
#     180         self.model.init_sims()
# --> 181         return self._build_from_model(self.model.vectors_norm, self.model.index2word, self.model.vector_size)
#     182
#     183     def _build_from_model(self, vectors, labels, num_features):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gensim/similarities/index.py in _build_from_model(self, vectors, labels, num_features)
#     185
#     186         for vector_num, vector in enumerate(vectors):
# --> 187             index.add_item(vector_num, vector)
#     188
#     189         index.build(self.num_trees)
#
# KeyboardInterrupt:

# %%
vector.shape

# %%
vector = word2vec.wv["ngon"]

# %%
approximate_neighbors = word2vec.wv.most_similar([vector], topn=11, indexer=annoy_index)
# Out:
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
print("Approximate Neighbors")
for neighbor in approximate_neighbors:
    print(neighbor)
# Out:
# Approximate Neighbors
# ('ngon', 0.999999578531515)
# ('thơm_ngon', 0.5760951042175293)
# ('tuyệt_ngon', 0.5611180663108826)
# ('ngon_miệng', 0.5596114993095398)
# ('lạ_miệng', 0.5486402213573456)
# ('bổ_dưỡng', 0.52823406457901)
# ('thanh_mát', 0.52445387840271)
# ('cơm_rang', 0.5227664709091187)
# ('nếp_cẩm', 0.5200028121471405)
# ('ngon_mắt', 0.5175403356552124)
# ('chua_chua_ngọt_ngọt', 0.5155121386051178)

# %%
normal_neighbors = word2vec.wv.most_similar([vector], topn=11)
print("\nNormal (not Annoy-indexed) Neighbors")
for neighbor in normal_neighbors:
    print(neighbor)
# Out:
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# Normal (not Annoy-indexed) Neighbors
# ('ngon', 1.0)
# ('thơm_ngon', 0.6406089663505554)
# ('tuyệt_ngon', 0.6147646307945251)
# ('ngon_miệng', 0.612115740776062)
# ('lạ_miệng', 0.592548131942749)
# ('bổ_dưỡng', 0.5548734664916992)
# ('thanh_mát', 0.5477113723754883)
# ('cơm_rang', 0.5444960594177246)
# ('nếp_cẩm', 0.5392052531242371)
# ('ngon_lành', 0.538558840751648)
# ('ngon_mắt', 0.5344654321670532)

# %%
model = word2vec

# %%
# Set up the model and vector that we are using in the comparison
# model.init_sims()
# annoy_index = AnnoyIndexer(model, 100)

# Dry run to make sure both indices are fully in RAM
vector = model.wv.vectors_norm[0]
model.wv.most_similar([vector], topn=5, indexer=annoy_index)
model.wv.most_similar([vector], topn=5)

import time
import numpy as np

def avg_query_time(annoy_index=None, queries=1000):
    """
    Average query time of a most_similar method over 1000 random queries,
    uses annoy if given an indexer
    """
    total_time = 0
    for _ in range(queries):
        rand_vec = model.wv.vectors_norm[np.random.randint(0, len(model.wv.vocab))]
        start_time = time.process_time()
        model.wv.most_similar([rand_vec], topn=5, indexer=annoy_index)
        total_time += time.process_time() - start_time
    return total_time / queries

queries = 10000

gensim_time = avg_query_time(queries=queries)
annoy_time = avg_query_time(annoy_index, queries=queries)
print("Gensim (s/query):\t{0:.5f}".format(gensim_time))
print("Annoy (s/query):\t{0:.5f}".format(annoy_time))
speed_improvement = gensim_time / annoy_time
print ("\nAnnoy is {0:.2f} times faster on average on this particular run".format(speed_improvement))
# Out:
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   import sys
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# Gensim (s/query):	0.16040
# Annoy (s/query):	0.00123
#
# Annoy is 130.19 times faster on average on this particular run

# %% [markdown]
# ### Save Persisting indices to disk

# %%
fname = 'annoy.index'

# Persist index to disk
annoy_index.save(fname)

# %%
# Load index back
import os.path
if os.path.exists('/Users/bubuhuy/Downloads/sentiment-classfication-exp/embeddings/annoy.index'):
    annoy_index2 = AnnoyIndexer()
    annoy_index2.load(fname)
    annoy_index2.model = model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5f1b1aa8bef1> in <module>
#       3 if os.path.exists('/Users/bubuhuy/Downloads/sentiment-classfication-exp/embeddings/annoy.index'):
#       4     annoy_index2 = AnnoyIndexer()
# ----> 5     annoy_index2.load(fname)
#       6     annoy_index2.model = model
#
# NameError: name 'fname' is not defined

# %%
# Results should be identical to above
vector = model.wv["ngon"]
approximate_neighbors2 = model.wv.most_similar([vector], topn=11, indexer=annoy_index2)
for neighbor in approximate_neighbors2:
    print(neighbor)

assert approximate_neighbors == approximate_neighbors2
# Out:
# ('ngon', 0.999999578531515)
# ('thơm_ngon', 0.5760951042175293)
# ('tuyệt_ngon', 0.5611180663108826)
# ('ngon_miệng', 0.5596114993095398)
# ('lạ_miệng', 0.5486402213573456)
# ('bổ_dưỡng', 0.52823406457901)
# ('thanh_mát', 0.52445387840271)
# ('cơm_rang', 0.5227664709091187)
# ('nếp_cẩm', 0.5200028121471405)
# ('ngon_mắt', 0.5175403356552124)
# ('chua_chua_ngọt_ngọt', 0.5155121386051178)
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
normal_neighbors3 = model.wv.most_similar([vector], topn=11)
print("\nNormal (not Annoy-indexed) Neighbors")
for neighbor in normal_neighbors3:
    print(neighbor)
# Out:
# /Users/bubuhuy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# Normal (not Annoy-indexed) Neighbors
# ('ngon', 1.0)
# ('thơm_ngon', 0.6406089663505554)
# ('tuyệt_ngon', 0.6147646307945251)
# ('ngon_miệng', 0.612115740776062)
# ('lạ_miệng', 0.592548131942749)
# ('bổ_dưỡng', 0.5548734664916992)
# ('thanh_mát', 0.5477113723754883)
# ('cơm_rang', 0.5444960594177246)
# ('nếp_cẩm', 0.5392052531242371)
# ('ngon_lành', 0.538558840751648)
# ('ngon_mắt', 0.5344654321670532)

# %% [markdown]
# ### Save memory via memory-mapping indices saved to disk
